# %% [markdown]
# # 서울대학교 예비대학 디딤돌 프로그램

# %% [markdown]
# # 실습 2일차: 입출력과 조건문

# %% [markdown]
# ## 📘 실습 이론 정리
# ### 1. 입력과 출력
# **입력(input)**
# * input() 함수는 사용자로부터 값을 입력받는다.
# * 입력받은 값은 항상 문자열(str) 형태이다.
# * 숫자 계산이 필요한 경우 반드시 형 변환을 해야 한다.
#
# **출력(print)**
# * print() 함수는 값을 화면에 출력한다.
# * 여러 값 출력이 가능하며, 문자열과 변수 값을 함께 출력할 수 있다.
# * f-string을 사용하면 출력 형식을 간단하게 작성할 수 있다.
#
# ### 2. 자료형 변환 (Type Casting)
#
# 문자열로 입력된 값을 계산에 사용하려면 자료형 변환이 필요하다.
#
# **함수**
# * int()	정수로 변환
# * float()	실수로 변환
# * str()	문자열로 변환
#
# ⚠️ 숫자로 변환할 수 없는 문자열을 변환하려고 하면 오류가 발생한다.
#
# ### 3. 조건문 (if 문)
# **기본 구조**
# * 조건이 참(True)이면 해당 블록이 실행된다.
# * 조건이 거짓(False)이면 다른 조건 또는 else 블록이 실행된다.
# * 조건문은 위에서 아래 순서대로 검사된다.
#
# **구성 요소**
# * if : 첫 번째 조건 검사
# * elif : 추가 조건 검사
# * else : 모든 조건이 거짓일 때 실행
#
# ### 4. 비교 연산자
#
# 조건문에서 두 값을 비교할 때 사용한다.
#
# **연산자	의미**
# * ==	같다
# * !=	다르다
# * \>	크다
# * <	작다
# * \>=	크거나 같다
# * <=	작거나 같다
#
# ⚠️ = 는 값을 대입하는 연산자이며, 비교에는 반드시 ==를 사용한다.
#
# ### 5. 논리 연산자
#
# 여러 조건을 동시에 검사할 때 사용한다.
#
# **연산자	의미**
# * and	두 조건이 모두 참일 때 참
# * or	하나라도 참이면 참
# * not	조건의 결과를 반대로
#
# ### 6. 문자열과 조건문
# * 문자열 비교 시에는 따옴표로 감싸야 한다.
# * 대소문자는 서로 다른 문자열로 인식된다.
# * 공백과 철자 차이도 다른 문자열로 처리된다.
#
# ### 7. 들여쓰기 (Indentation)
# * 파이썬에서 들여쓰기는 문법의 일부이다.
# * 조건문 내부 코드는 반드시 들여쓰기 해야 한다.
# * 들여쓰기가 잘못되면 오류가 발생하거나 의도와 다른 결과가 나온다.

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 입력문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 입력문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('입력문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 입력문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ### (실습) Problem 1: 월급 계산
#
# 😄 input()으로 연봉을 입력받은 다음, 월급을 출력하여라. 회사는 연봉을 12개월로 나누어 매달 지급하며 1원 미만은 버린다.
#
# ---
# Input Sample
# ```
# 43000000
# ```
# Output Sample
# ```
# 3583333
# ```

# %% [markdown]
# 📜 참고: 사용자로부터 입력받는 연봉은 숫자가 아니라 문자라는 점에 특히 유의해야 한다.
# 문자를 입력받았으므로 사칙연산을 수행하기 위해서는 반드시 입력받은 값을 숫자로 바꾸어야 한다.

# %%
salary = int(input())
print(salary // 12)
# Out:
# 43000000
# 3583333

# %% [markdown]
# ### (실습) Problem 2: 홀수 짝수 검사
# 😄 숫자를 입력 받아 짝수인지 홀수인지 검사하는 프로그램을 나머지 연산자(%)를 이용하여 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 97
# ```
# Output Sample
# ```
# 숫자를 입력하시오:
# 홀수입니다.
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 76
# ```
# Output Sample
# ```
# 숫자를 입력하시오:
# 짝수입니다.
# ```

# %% [markdown]
# ⚠️ 주의: Python에서 '같다'를 뜻하는 비교 연산자는 =이 아니라 ==임에 주의한다.

# %%
num = int(input("숫자를 입력하시오: "))

if num % 2 == 0:
    print("짝수입니다.")
else:
    print("홀수입니다.")
# Out:
# 숫자를 입력하시오: 97
# 홀수입니다.

# %% [markdown]
# ### (실습) Problem 3: 운전면허 합격 불합격
# 😄 운전면허 1종 보통의 경우 학과시험 점수가 70점 이상 시 합격이다. 점수를
# 입력받아 70점 이상이면 합격을 70점 미만이면 불합격을 출력하는 코드를 작성하여라.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 77
# ```
# Output Sample
# ```
# 학과시험 점수를 입력하시오:
# 축하! 축하! 합격입니다.
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 63
# ```
# Output Sample
# ```
# 학과시험 점수를 입력하시오:
# 이런...불합격입니다.
# ```

# %%
score = int(input("학과시험 점수를 입력하시오: "))

if score >= 70:
    print("축하! 축하! 합격입니다.")
else:
    print("이런...불합격입니다.")
# Out:
# 학과시험 점수를 입력하시오: 77
# 축하! 축하! 합격입니다.

# %% [markdown]
# ### (실습) Problem 4: 두 수의 합과 차
#
# 😄 정수 두 개를 입력받아 합과 차(큰 수 - 작은 수)를 출력하시오
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 10
# 3
# ```
#
# Output Sample
#
# ```
# 정수 1을 입력하시오:
# 정수 2을 입력하시오:
# 합: 13
# 차: 7
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 6
# 17
# ```
#
# Output Sample
#
# ```
# 정수 1을 입력하시오:
# 정수 2을 입력하시오:
# 합: 23
# 차: 11
# ```

# %%
a = int(input("정수 1을 입력하시오: "))
b = int(input("정수 2을 입력하시오: "))

print(f"합: {a + b}")

if a >= b:
    print(f"차: {a - b}")
else:
    print(f"차: {b - a}")
# Out:
# 정수 1을 입력하시오: 10
# 정수 2을 입력하시오: 3
# 합: 13
# 차: 7

# %% [markdown]
# ### (실습) Problem 5: 부가세 계산
# 😄 합계금액을 입력받고 아래 공식을 이용하여 부가세를 계산하는 프로그램을 작성하세요.
#
# 📜Hint: round 함수를 사용하면 소수점 자릿수를 지정하여 반올림할 수 있습니다. round 함수의 사용 형식은 round(실수, n)이며, 소수점 n째 자리까지 표현되도록 실수의 반올림을 수행한다. 위 코드와 같이 n을 입력하지 않고 곧장 사용할 경우 가장 가까운 정수로 반올림하게 된다.
#
# 부가세 계산 공식
# ```
# 합계금액 * (10/110)
# ```
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 100000
#
# ```
# Output Sample
# ```
# 부가세 계산 프로그램
#
# 합계금액을 입력하세요:
# 공급가액 90909원
# 세액 9091원입니다.
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 250000
#
# ```
# Output Sample
# ```
# 부가세 계산 프로그램
#
# 합계금액을 입력하세요:
# 공급가액 227273원
# 세액 22727원입니다.
# ```

# %%
print("부가세 계산 프로그램")

total = int(input("합계금액을 입력하세요: "))

tax = round(total * (10 / 110))
price = total - tax

print(f"공급가액 {price}원")
print(f"세액 {tax}원입니다.")
# Out:
# 부가세 계산 프로그램
# 합계금액을 입력하세요: 100000
# 공급가액 90909원
# 세액 9091원입니다.

# %% [markdown]
# ### (과제) Problem 6: 큰 수, 작은 수, 같은 수 판별하기
# 😄 아래와 같이 두 수를 입력 받아 큰 수, 작은 수, 같은 수를 출력하는 프로그램을 작성하세요.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 100
# 200
# ```
# Output Sample
# ```
# 첫 번째 정수를 입력하시오:
# 두 번째 정수를 입력하시오:
# 큰 수: 200
# 작은 수: 100
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 56
# 24
# ```
# Output Sample
# ```
# 첫 번째 정수를 입력하시오:
# 두 번째 정수를 입력하시오:
# 큰 수: 56
# 작은 수: 24
# ```
#
# <font color='blue'>`Test case-3`</font>
#
# Input Sample
# ```
# 45
# 45
# ```
# Output Sample
# ```
# 첫 번째 정수를 입력하시오:
# 두 번째 정수를 입력하시오:
# 두 수는 같습니다.
# ```

# %% [markdown]
# ⚠️ 주의: input을 통해 입력받은 num1과 num2의 값은 문자이다.
# 이를 숫자로 바꾸지 않고 코드를 작성할 경우 문자끼리 비교가 이루어지기에 잘못된 결과가 출력될 수 있다.
# 예를 들어 숫자로의 변환 과정 없이 코드를 작성한 후 num1에 13 를 입력하고 num2에 8을 입력해 보자.
# 그러면 13이 8보다 더 큼에도 불구하고 큰수로 8이 출력되고 작은수로 13이 출력됨을 확인할 수 있다.

# %%
a = int(input("첫 번째 정수를 입력하시오: "))
b = int(input("두 번째 정수를 입력하시오: "))

if a > b:
    print(f"큰 수: {a}")
    print(f"작은 수: {b}")
elif a < b:
    print(f"큰 수: {b}")
    print(f"작은 수: {a}")
else:
    print("두 수는 같습니다.")
# Out:
# 첫 번째 정수를 입력하시오: 100
# 두 번째 정수를 입력하시오: 200
# 큰 수: 200
# 작은 수: 100

# %% [markdown]
# ### (실습) Problem 7: 스마트 온도 변환기
# 😄 온도와 단위를 입력받아 자동으로 변환하는 프로그램을 작성하시오.
#
#
# *   단위가 "C"이면 섭씨 -> 화씨 변환
# *   단위가 "F"이면 화씨 -> 섭씨 변환
# *   그 외 입력시 "잘못된 단위입니다." 출력
# *   결과는 소수점 첫째 자리까지 출력
#
#
#
#
#
# 변환 공식
#
# <font color='blue'>`화씨(f) → 섭씨(c)`</font>
# ```python
# c = 5.0 / 9.0 * (f - 32.0)
# ```
# <font color='blue'>`섭씨(c) → 화씨(f)`</font>
# ```python
# f = 9.0 / 5.0 * c + 32.0
# ```
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 25
# C
# ```
#
# Output Sample
#
# ```
# 온도 변환 프로그램
#
# 온도를 입력하세요:
# 단위를 입력하세요:
#
# 변환된 온도: 77.0F
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 80
# F
# ```
#
# Output Sample
#
# ```
# 온도 변환 프로그램
#
# 온도를 입력하세요:
# 단위를 입력하세요:
#
# 변환된 온도: 26.7C
# ```
#
# <font color='blue'>`Test case-3`</font>
#
# Input Sample
# ```
# 10
# K
# ```
#
# Output Sample
#
# ```
# 온도 변환 프로그램
#
# 온도를 입력하세요:
# 단위를 입력하세요:
#
# 잘못된 단위입니다.
# ```

# %%
print("온도 변환 프로그램")
print("")

temp = float(input("온도를 입력하세요: "))
unit = input("단위를 입력하세요: ")
print("")

if unit == "C":
    result = round((9.0 / 5.0) * temp + 32.0, 1)
    print(f"변환된 온도: {result}F")
elif unit == "F":
    result = round((5.0 / 9.0) * (temp - 32.0), 1)
    print(f"변환된 온도: {result}C")
else:
    print("잘못된 단위입니다.")
# Out:
# 온도 변환 프로그램
#
# 온도를 입력하세요: 10
# 단위를 입력하세요: K
#
# 잘못된 단위입니다.

# %% [markdown]
# ### (실습) Problem 8: 놀이공원 입장 요금 계산기
# 😄 나이와 방문 요일을 입력받아 놀이공원 입장 요금을 계산하시오.
#
# ***요금 기준***
#
# *   어린이 (13세 미만): 5,000원
# *   청소년 (13세 이상 18세 이하): 8,000원
# *   성인 (19세 이상): 12,000원
#
# ***할인 규칙***
#
# *   방문 요일이 "평일"이면 20% 할인
# *   "주말"이면 할인 없음
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 10
# 평일
# ```
#
# Output Sample
#
# ```
# 나이:
# 방문 요일:
# 입장 요금: 4000원
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 20
# 주말
# ```
#
# Output Sample
#
# ```
# 나이:
# 방문 요일:
# 입장 요금: 12000원
# ```

# %%
age = int(input("나이: "))
day = input("방문 요일: ")

if age < 13:
    fee = 5000
elif age <= 18:
    fee = 8000
else:
    fee = 12000

if day == "평일":
    fee = int(fee * 0.8)

print(f"입장 요금: {fee}원")
# Out:
# 나이: 20
# 방문 요일: 주말
# 입장 요금: 12000원

# %% [markdown]
# ---

# %% [markdown]
# 본 자료는 대한민국 저작권법을 준수합니다. 본 자료는 서울대학교 예비 대학생들의 수업목적으로 제작&배포되는 것이므로 수업목적 이외에 다른 용도로 사용할 수 없으며, 다른 장소 및 타인에게 복제, 전송하여 공유할 수 없습니다. 이를 위반해서 발생하는 모든 법적 책임은 행위 주체인 본인에게 있습니다.
# 실습 문제&솔루션에 대한 질문이 있다면, 아래로 연락 주세요.
# ladybhs@snu.ac.kr
#
# 서울대학교 예비대학 컴퓨팅분야 담당교수 변해선
