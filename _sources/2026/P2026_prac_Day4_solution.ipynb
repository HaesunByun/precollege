# %% [markdown]
# # 서울대학교 예비대학 디딤돌 프로그램

# %% [markdown]
# # 실습 4일차: 리스트

# %% [markdown]
# ## 📘 실습 이론 정리
# ### 1. 리스트란?
# * 리스트(list)는 여러 개의 값을 하나의 변수에 순서대로 저장하는 자료형이다.
# * 대괄호 []를 사용하여 생성한다.
# * 리스트에는 문자열, 숫자, 실수 등 다양한 자료형을 함께 저장할 수 있다.
# * 리스트는 **순서(index)**를 가지며, 중복된 값도 허용한다.
# ### 2. 리스트의 특징
# * 순서가 있다
# → 각 원소는 인덱스(index)를 통해 접근 가능
# * 수정 가능하다 (mutable)
# → 생성 후에도 값 변경 가능
# * 중복 허용
# * 여러 개의 값을 한 번에 관리할 수 있어 반복문과 함께 자주 사용된다
# ### 3. 리스트와 인덱스(Index)
# * 리스트의 인덱스는 0부터 시작한다.
# * 음수 인덱스를 사용하면 뒤에서부터 접근할 수 있다.
# * 인덱스를 통해 특정 위치의 값을 읽거나 수정할 수 있다.
#
# ⚠️ 존재하지 않는 인덱스에 접근하면 오류(IndexError)가 발생한다.
#
# ### 4. 리스트의 길이
# * len() 함수를 사용하면 리스트에 저장된 원소의 개수를 알 수 있다.
# * 반복문에서 리스트를 다룰 때 자주 사용된다.
# ### 5. 리스트와 반복문
# * 리스트는 반복문(for, while)과 함께 자주 사용된다.
# * 리스트의 모든 원소를 하나씩 처리할 때 매우 유용하다.
# * 반복문을 사용하면 리스트의 각 원소에 대해 동일한 작업을 수행할 수 있다.
# ### 6. 리스트에 값 추가 및 삭제
# * 리스트는 실행 중에도 값의 추가와 삭제가 가능하다.
# * 값 추가: 리스트의 끝에 새로운 값을 넣을 수 있다.
# * 값 삭제: 특정 값이나 특정 위치의 값을 제거할 수 있다.
#
# ⚠️ 삭제 시 존재하지 않는 값을 제거하려 하면 오류가 발생할 수 있다.
#
# ###7. 리스트와 문자열
# * 문자열은 문자의 리스트처럼 다룰 수 있다.
# * 문자열을 공백 기준으로 나누면 리스트가 된다.
# * 리스트의 각 원소는 문자열 처리와 조건문과 함께 자주 사용된다.
#
# ### 8. 리스트 정렬과 순서
# * 리스트는 정렬하여 사용할 수 있다.
# * 오름차순 또는 내림차순 정렬이 가능하다.
# * 정렬 후에는 리스트의 원소 순서가 변경된다.
# ### 9. 리스트 사용 시 자주 하는 실수
# * 인덱스를 1부터 시작한다고 착각하는 경우
# * 리스트 길이를 넘는 인덱스에 접근하는 경우
# * 문자열과 리스트를 혼동하는 경우
# * 리스트를 복사하지 않고 그대로 참조해서 사용하는 경우

# %% [markdown]
# ### (실습) Problem 1: 저녁 메뉴 추천
#
# 😄 1)먹고 싶은 음식 메뉴를 담은 리스트를 하나 만드시오.
#
#
# > 예 ['샌드위치', '떡볶이', '피자', '햄버거']
#
# 2) 앞서 만든 리스트에서 임의로 하나를 택하여, '오늘 저녁 메뉴로 OOO를 추천합니다'와 같은 형식으로 출력하는 코드를 작성하시오
#
# * 임의의 정수는 random.randint 를 사용하여 생성
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Output Sample
# ```
# 오늘 저녁 메뉴로 샌드위치를 추천합니다.
# ```
# <font color='blue'>`Test case-2`</font>
#
# Output Sample
# ```
# 오늘 저녁 메뉴로 피자를 추천합니다.
# ```

# %%
import random

menu = ['샌드위치', '떡볶이', '피자', '햄버거']
idx = random.randint(0, len(menu) - 1)

print(f"오늘 저녁 메뉴로 {menu[idx]}를 추천합니다.")
# Out:
# 오늘 저녁 메뉴로 햄버거를 추천합니다.

# %% [markdown]
# ### (실습) Problem 2: 문자열 개수 파악
#
# 😄 문자열을 입력받아 그 문자열에 알파벳 a 가 몇 번 등장하는지를 출력하는 코드를 작성하시오.
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# I wanna dance, the music's got me going ain't nothing that can stop how we move, yeah
# ```
#
# Output Sample
#
# ```
# Input:
# 7
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# A drowning man will catch at a straw
# ```
#
# Output Sample
#
# ```
# Input:
# 6
# ```

# %%
text = input("Input:")
count = 0

for ch in text:
    if ch == 'a' or ch == 'A':
        count += 1

print(count)
# Out:
# Input:I wanna dance, the music's got me going ain't nothing that can stop how we move, yeah
# 7

# %% [markdown]
# ### (실습) Problem 3: 동이름 출력하기
# 😄 구이름과 동이름을 입력 받아 그 중 동이름만 출력하는 프로그램을 작성하시오.
#
# ---
#
# Input Sample
# ```
# 강동구 노원구 용산구 상암동 서울시 논현동 평창동 중구
# ```
# Output Sample
# ```
# In:
# ===
# 동이름
# ===
# 상암동
# 논현동
# 평창동
# ```

# %%
# while 활용
text = input("In: ")
words = text.split()

print("===")
print("동이름")
print("===")

i = 0
while i < len(words):
    if words[i][-1] == "동":
        print(words[i])
    i += 1
# Out:
# In: 강동구 노원구 용산구 상암동 서울시 논현동 평창동 중구
# ===
# 동이름
# ===
# 상암동
# 논현동
# 평창동

# %%
# for 활용
text = input("In: ")
words = text.split()

print("===")
print("동이름")
print("===")

for word in words:
    if word[-1] == "동":
        print(word)
# Out:
# In: 강동구 노원구 용산구 상암동 서울시 논현동 평창동 중구
# ===
# 동이름
# ===
# 상암동
# 논현동
# 평창동

# %% [markdown]
# ### (실습) Problem 4: 리스트 합/평균 구하기
# 😄 정수들이 문자열 형태로 주어질 때, 리스트로 저장한 뒤 합과 평균(소수점 1자리)를 출력하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 10 20 30 40
# ```
# Output Sample
# ```
# Input:
# 합: 100
# 평균: 25.0
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 1 7 56 18 40 11
# ```
# Output Sample
# ```
# Input:
# 합: 133
# 평균: 22.2
# ```

# %%
text = input("Input: ")
nums = text.split()

total = 0
count = 0

for n in nums:
    total += int(n)
    count += 1

avg = round(total / count, 1)

print(f"합: {total}")
print(f"평균: {avg}")
# Out:
# Input: 10 20 30 40
# 합: 100
# 평균: 25.0

# %% [markdown]
# ### (실습) Problem 5: 중복없이 네 개의 수 출력
# 😄 1에서 10 까지 수 가운데 중복 없이 네 개의 수를 무작위로 출력하는 코드를 작성하시오. 수는 반드시 오름차순으로 출력되어야 한다.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Output Sample
# ```
# [4, 7, 8, 9]
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Output Sample
# ```
# [2, 4, 5, 8]
# ```

# %%
import random

nums = []

while len(nums) < 4:
    n = random.randint(1, 10)
    if n not in nums:
        nums.append(n)

nums.sort()
print(nums)
# Out:
# [2, 3, 4, 10]

# %% [markdown]
# ### (실습) Problem 6: 369 게임 1
# 😄 369게임에서 참가자는 3/6/9 중 적어도 하나의 숫자가 포함되는 순번에서 박수를 친다.
# 이를테면 21 순번에서 참가자는 21을 외치며 37 순번에서 참가자는 '짝'을 외친다.
# 순번이 입력되었을 때 참가자가 외쳐야 할 말을 출력하는 프로그램을 작성하시오.
# 박수를 두 번 이상 치는 경우는 고려하지 않는다.
# 이를테면 139 순번에서 참가자는 '짝짝'이 아니라 '짝'을 외친다.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 21
# ```
#
# Output Sample
# ```
# 369! 369!
# 순번을 입력하세요:
# 21
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 37
# ```
#
# Output Sample
# ```
# 369! 369!
# 순번을 입력하세요:
#
# ```

# %%
print("369! 369!")
num = input("순번을 입력하세요: ")

clap = False

for ch in num:
    if ch == '3' or ch == '6' or ch == '9':
        clap = True

if clap:
    print("짝")
else:
    print(num)
# Out:
# 369! 369!
# 순번을 입력하세요: 21
# 21

# %% [markdown]
# ### (과제) Problem 7: 369 게임 2
#
# 😄 컴퓨터와 사용자 둘 중 한 쪽이 이길 때까지 계속되는 369 게임을 구현하시오. 컴퓨터가
# 항상 먼저 게임을 시작하며 박수를 두 번 이상 치는 경우는 고려하지 않는다.
# 컴퓨터는 자신의 차례에서 절대 틀리지 않는다.
# 게임 진행 내역을 리스트에 저장했다가, 게임 종료 시 전체 내역을 한 번에 출력한다.
#
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 2
# 4
# 짝
# 8
# 10
# 12
# 짝
# ```
#
# Output Sample
# ```
# 369! 369!
# 컴퓨터: 1
# 나:
# 컴퓨터: 짝
# 나:
# 컴퓨터: 5
# 나:
# 컴퓨터: 7
# 나:
# 컴퓨터: 짝
# 나:
# 컴퓨터: 11
# 나:
# 컴퓨터: 짝
# 나:
# COMPUTER WIN!
# 기록: ['컴퓨터: 1', '나: 2', '컴퓨터: 짝', '나: 4', '컴퓨터: 5', '나: 짝', '컴퓨터: 7', '나: 8', '컴퓨터: 짝', '나: 10', '컴퓨터: 11', '나: 12', '컴퓨터: 짝', '나: 짝']
# ```

# %%
print("369! 369!")

log = []
num = 1
win = False

while not win:
    # 컴퓨터 차례
    clap = False
    for ch in str(num):
        if ch == '3' or ch == '6' or ch == '9':
            clap = True

    if clap:
        say = "짝"
    else:
        say = str(num)

    print(f"컴퓨터: {say}")
    log.append(f"컴퓨터: {say}")

    num += 1

    # 사용자 차례
    user = input("나: ")
    log.append(f"나: {user}")

    clap = False
    for ch in str(num):
        if ch == '3' or ch == '6' or ch == '9':
            clap = True

    if clap:
        answer = "짝"
    else:
        answer = str(num)

    if user != answer:
        print("COMPUTER WIN!")
        win = True
    else:
        num += 1

print(f"기록: {log}")
# Out:
# 369! 369!
# 컴퓨터: 1
# 나: 2
# 컴퓨터: 짝
# 나: 4
# 컴퓨터: 5
# 나: 짝
# 컴퓨터: 7
# 나: 8
# 컴퓨터: 짝
# 나: 10
# 컴퓨터: 11
# 나: 12
# 컴퓨터: 짝
# 나: 짝
# COMPUTER WIN!
# 기록: ['컴퓨터: 1', '나: 2', '컴퓨터: 짝', '나: 4', '컴퓨터: 5', '나: 짝', '컴퓨터: 7', '나: 8', '컴퓨터: 짝', '나: 10', '컴퓨터: 11', '나: 12', '컴퓨터: 짝', '나: 짝']

# %% [markdown]
# ### (실습) Problem 8: 장바구니 정리
#
# 😄 사용자가 입력한 장바구니 목록을 리스트로 만든 뒤,
# 1. 중복을 제거한 구매 목록을 입력 순서대로 출력하고
# 2. 각 품목이 몇 번 등장했는지 요약해서 출력하시오.
#
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 우유 빵 우유 라면 빵 빵
# ```
#
# Output Sample
# ```
# 장바구니:
# 구매 목록: ['우유', '빵', '라면']
# 우유: 2
# 빵: 3
# 라면: 1
# ```

# %%
text = input("장바구니: ")
items = text.split()

uniq = []
count = []

for item in items:
    found = False
    i = 0
    while i < len(uniq):
        if uniq[i] == item:
            count[i] += 1
            found = True
        i += 1

    if not found:
        uniq.append(item)
        count.append(1)

print(f"구매 목록: {uniq}")

i = 0
while i < len(uniq):
    print(f"{uniq[i]}: {count[i]}")
    i += 1
# Out:
# 장바구니: 우유 빵 우유 라면 빵 빵
# 구매 목록: ['우유', '빵', '라면']
# 우유: 2
# 빵: 3
# 라면: 1

# %% [markdown]
# ---

# %% [markdown]
# 본 자료는 대한민국 저작권법을 준수합니다. 본 자료는 서울대학교 예비 대학생들의 수업목적으로 제작&배포되는 것이므로 수업목적 이외에 다른 용도로 사용할 수 없으며, 다른 장소 및 타인에게 복제, 전송하여 공유할 수 없습니다. 이를 위반해서 발생하는 모든 법적 책임은 행위 주체인 본인에게 있습니다.
# 실습 문제&솔루션에 대한 질문이 있다면, 아래로 연락 주세요.
# ladybhs@snu.ac.kr
#
# 서울대학교 예비대학 컴퓨팅분야 담당교수 변해선
