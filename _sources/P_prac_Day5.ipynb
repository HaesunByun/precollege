# %% [markdown]
# # 서울대학교 예비대학 디딤돌 프로그램

# %% [markdown]
# # 실습 5일차: 함수

# %% [markdown]
# ### Problem 1: 카레 물의 양
#
# 😄 물 9컵과 카레 가루 1.5 컵을 넣으면 맛있는 카레를 만들 수 있다. 이 방법대로 맛있는 카레를 만들기 위해, 카레의 양을 입력 받아 물의 양을 반환하는 함수를 정의하시오. 단, 단위는 컵이라 가정한다.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 1.5
# ```
#
# Output Sample
# ```
# 카레가루 양:
# 9.0
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 4
# ```
#
# Output Sample
# ```
# 카레가루 양:
# 24.0
# ```

# %%
def curry_water(powder):

# %% [markdown]
# ### Problem 2: 리스트 합 구하기
#
# 😄 리스트를 인자로 받아 리스트의 모든 항목의 합을 반환하는 함수를 정의하시오.
# 단, 전달 받은 리스트의 항목은 모두 정수다.
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Output Sample
# ```
# 6
# ```
#
# <font color='blue'>`Test case-2`</font>
# Output Sample
# ```
# 265
# ```

# %%
#Todo

list_sum([1,2,3])

# %%
list_sum([40,60,30,90,45])

# %% [markdown]
# ### Problem 3: 가장 큰 수
#
# 😄 세 개의 자연수를 입력 받아 가장 큰 수를 반환하는 함수를 정의하시오. 단, 수는 if 문을 사용해서 비교하시오.
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 10
# 20
# 30
# ```
# Output Sample
# ```
# Input:
# Input:
# Input:
# 30
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 123
# 99
# 28
# ```
# Output Sample
# ```
# Input:
# Input:
# Input:
# 123
# ```

# %% [markdown]
# ### Problem 4: 입력받은 수 까지의 합
# 😄 1부터 입력 받은 수까지의 합을 구하는 프로그램을 함수를 정의하여 작성하시오. 단,
# 입력과 출력은 함수 밖에서 이루어집니다
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 100
# ```
# Output Sample
# ```
# 수를 입력하세요:
# 1 부터 100 까지의 합은 5050 입니다.
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# -50
# ```
# Output Sample
# ```
# 수를 입력하세요:
# 1 이상의 수를 입력하셔야 합니다.
# ```

# %% [markdown]
# ---

# %% [markdown]
# 본 자료는 대한민국 저작권법을 준수합니다. 본 자료는 서울대학교 예비 대학생들의 수업목적으로 제작&배포되는 것이므로 수업목적 이외에 다른 용도로 사용할 수 없으며, 다른 장소 및 타인에게 복제, 전송하여 공유할 수 없습니다. 이를 위반해서 발생하는 모든 법적 책임은 행위 주체인 본인에게 있습니다.
# 실습 문제&솔루션에 대한 질문이 있다면, 아래로 연락 주세요.
# ladybhs@snu.ac.kr
#
# 서울대학교 예비대학 컴퓨팅분야 담당교수 변해선
