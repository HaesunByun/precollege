# %% [markdown]
# # 서울대학교 예비대학 디딤돌 프로그램

# %% [markdown]
# # Homework-Day4:

# %% [markdown]
# ### Problem: 월 영문으로 출력하기
# 😄 숫자 월을 입력받아 그것에 대한 영문 월을 출력하시오.
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 3
# ```
# Output Sample
# ```
# 월을 입력하세요(1~12):
# 입력된 월은 March 입니다.
# ```
# ---
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 7
# ```
# Output Sample
# ```
# 월을 입력하세요(1~12):
# 입력된 월은 July 입니다.
# ```

# %%
# Out:
# 월을 입력하세요(1~12): 4
# 입력된 월은 April 입니다.

# %% [markdown]
# ### Problem: 나만의 영어단어장
# 😄 영어 단어를 입력받아 나만의 영어 단어장을 만드는 프로그램을 작성하시오. End를 입력받으면 단어입력을 멈춥니다.
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# Apple
# Banana
# Coconut
# Durian
# End
# ```
# Output Sample
#
# ```
# 나만의 영어 단어장
#
# Input:
# Input:
# Input:
# Input:
# Input:
# 영어단어장: [Apple, Banana, Coconut, Durian]
# ```
